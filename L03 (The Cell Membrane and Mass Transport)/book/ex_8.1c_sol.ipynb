# %% [markdown]
# # Exercise 8.1c solution

# %%
Cm = 0.05  # nF
dV = 120  # mV
dQ = Cm * dV

# Note: nF * mV = (10^-9 F) * (10^-3 V) = 10^-12 C = pC
print(f"Approximately {dQ:.1f} pC travels through the membrane.")
# Out:
# Approximately 6.0 pC travels through the membrane.

# %% [markdown]
# 6 **pico**coulombs is an absolutely tiny amount of charge. Of course, the cell itself is also tiny, so it is a bit hard to interpret this answer in relative terms just yet.
