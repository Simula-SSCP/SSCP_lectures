# %% [markdown]
# # Exercise 8.1: Calculating Nernst potentials
#
# The following table gives typical values for mammalian cardiomyocytes and is taken from _[Katz, 2010]_.
#
# | Ion            | Intracellular | Extracellular |
# | -------------- | :-----------: | ------------: |
# | Sodium (Na⁺)   |     8 mM      |        110 mM |
# | Potassium (K⁺) |    100 mM     |          4 mM |
# | Calcium (Ca²⁺) |    0.2 µM     |          1 mM |
#
# You will also need to know these physical constants:
#
# | Name               | Symbol | Value |      Unit |
# | ------------------ | :----: | ----: | --------: |
# | Faraday's constant |  $F$   | 96485 |     C/mol |
# | Gas constant       |  $R$   | 8.314 | J/(mol K) |
# | Temperature        |  $T$   |   310 |         K |
#
# <br>
#
# ## Exercise 8.1a: Computing the Nernst potentials
#
# Based on the tabulated values, calculate the Nernst potentials for the three ionic species using the formula:
#
# $$
# E_{\mathrm{X}} = \frac{R T}{z F} \ln \frac{[\mathrm{X}]_{\mathrm{e}}}{[\mathrm{X}]_{\mathrm{i}}}
# $$
#
# Print out the potentials in units of millivolts (mV).

# %%
import numpy as np

F = ...
R = ...
T = ...

E_Na = ...
E_K = ...
E_Ca = ...

# Print your answers here

# %% [markdown]
# ## Exercise 8.1b: Interpreting the sign of the Nernst potential
#
# You should have received two positive answers and one negative answer. Explain why this is the case based on the physical gradients.

# %% [markdown]
# ## Exercise 8.1c: How much current is needed to charge the membrane?
#
# Assume we have a membrane that is resting at a potential of -80 mV. Sodium channels in the membrane now open, and sodium ions flow into the cell until the membrane potential reaches a new equilibrium, this one at +40 mV.
#
# As the membrane behaves as a capacitor, the total charge that passes through the membrane can be approximated by:
#
# $$
# \Delta Q = C_{\mathrm{m}} \Delta V
# $$
#
# Use this formula to estimate the total amount of charge that crosses the membrane if the membrane capacitance is 0.05 nF.

# %%
Cm = ...
dV = ...
dQ = ...

# %% [markdown]
# ## Exercise 8.1d: Number of particles
#
# You can use Faraday's constant to go from a given charge to the total number of charged particles (in terms of moles):
# $F = 96485$ C/mol.
#
# Roughly how many moles of Na⁺ ions must cross the membrane to change the membrane potential from -80 mV to +40 mV?

# %%
dNa = ...

# %% [markdown]
# ## Exercise 8.1e: Change in concentration
#
# Assuming the cell has a total internal volume of 20 picoliters, how much does the global intracellular sodium concentration actually change as a result of this influx?

# %%
V_cell = ...
dconc = ...

# %% [markdown]
# ## Exercise 8.1f: Perturbing the Nernst potential
#
# In (8.1a), you found the Nernst potential for sodium under normal physiological conditions. Assume now that the intracellular sodium concentration of the cell has increased by 30%. How much does its Nernst potential change?

# %%
E_Na = R * T / F * np.log(... / ...)
print(f"Original E_Na:              {E_Na:.1f} mV")

E_Na = R * T / F * np.log(... / ...)
print(f"After 30% increase in Na:   {E_Na:.1f} mV")

# %% [markdown]
# ## Exercise 8.1g: Is the Nernst potential a constant? (Discuss)
#
# Based on your answers to the last two sub-exercises, explain why the Nernst potential is frequently considered a constant in electrophysiological models, despite it technically being a dynamic function of the intracellular and extracellular concentrations.
