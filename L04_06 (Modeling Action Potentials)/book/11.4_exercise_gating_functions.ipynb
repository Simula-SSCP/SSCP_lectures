# %% [markdown]
# # Exercise 11.1: Building gating functions in Python
#
# In this exercise, we will take the mathematical equations for Hodgkin-Huxley gating and implement them in Python.
#
# Let us assume we are modeling the activation gate ($m$) of a generic sodium channel. The mass action rate constants for this gate are known to follow these voltage-dependent exponential forms:
#
# $$
# \alpha_m(V) = 0.1 \frac{V + 40}{1 - \exp\left(-\frac{V + 40}{10}\right)}
# $$
#
# $$
# \beta_m(V) = 4.0 \exp\left(-\frac{V + 65}{18}\right)
# $$
#
# _(Note: In these equations, $V$ is the membrane potential in millivolts)._

# %% [markdown]
# ## Exercise 11.1a: Writing the rate functions
#
# Write two Python functions, `alpha_m(V)` and `beta_m(V)`, that take a voltage array `V` as an argument and return the calculated rates using the formulas above.
#
# _Hint: Use `np.exp()` so that your functions can gracefully handle entire NumPy arrays of voltages at once!_

# %%
import numpy as np
import matplotlib.pyplot as plt


def alpha_m(V):
    # Your code here
    return ...


def beta_m(V):
    # Your code here
    return ...

# %% [markdown]
# ## Exercise 11.1b: Calculating steady-state and time constants
#
# As discussed in the text, electrophysiologists rarely look directly at $\alpha$ and $\beta$. Instead, they prefer the steady-state activation ($m_\infty$) and the time constant ($\tau_m$).
#
# Recall the formulas:
#
# $$
# m_\infty(V) = \frac{\alpha_m(V)}{\alpha_m(V) + \beta_m(V)}
# $$
#
# $$
# \tau_m(V) = \frac{1}{\alpha_m(V) + \beta_m(V)}
# $$
#
# Write two Python functions, `m_inf(V)` and `tau_m(V)`. Inside these functions, you should simply call your `alpha_m` and `beta_m` functions and combine them mathematically!

# %%
def m_inf(V):
    # Your code here
    return ...


def tau_m(V):
    # Your code here
    return ...

# %% [markdown]
# ## Exercise 11.1c: Plotting the voltage dependence
#
# We now want to visualize the exact biological behavior of this sodium channel's activation gate.
#
# 1. Create a NumPy array of voltages ranging from -100 mV to +50 mV.
# 2. Calculate the corresponding arrays for $m_\infty$ and $\tau_m$ across this voltage range.
# 3. Plot both curves. (It is usually best to plot them in two separate subplots or figures, because probability goes from 0 to 1, while the time constant is measured in milliseconds).

# %%
# 1. Create voltage array
V_array = ...

# 2. Calculate m_inf and tau_m
# ...

# 3. Plot the results
# ...

# %% [markdown]
# ## Exercise 11.1d: Interpreting the plots
#
# Look at the plots you just generated.
#
# 1. At a resting membrane potential of -80 mV, what is the target open probability of the activation gate?
# 2. If the cell suddenly depolarizes to 0 mV, what happens to the target open probability?
# 3. Looking at the $\tau_m$ plot, at roughly what voltage is the time constant the slowest?
