# %% [markdown]
# # Exercise 11.2: Voltage-dependent gating
#
# In the previous exercise, we explored gating with constant rate constants. In reality, $\alpha$ and $\beta$ depend on the membrane voltage $V$. In this exercise, you will use an interactive widget to explore how the parameters of voltage-dependent rate functions shape the steady-state curve $m_\infty(V)$ and the time constant curve $\tau_m(V)$.

# %% [markdown]
# ## 11.2a: Understanding the exponential rate functions
#
# We will use exponential rate functions of the form:
#
# $$\alpha(V) = e^{(V - V_\alpha)/d_\alpha}, \qquad \beta(V) = e^{(V - V_\beta)/d_\beta}$$
#
# Before using the widget, answer the following:
#
# 1. What are the values of $\alpha(V_\alpha)$, $\alpha(V_\alpha + d_\alpha)$, and $\alpha(V_\alpha - d_\alpha)$?
#
# 2. For $d_\alpha > 0$, is $\alpha$ an increasing or decreasing function of $V$? What about for $d_\alpha < 0$?

# %% [markdown]
# ## 11.2b: Widget exploration
#
# Run the widget below and answer the questions that follow.

# %%
from widgets import voltage_dependence_widget

voltage_dependence_widget()

# %% [markdown]
# **Tasks:**
#
# 1. **Sharp transition:** Find a parameter set where $m_\infty(V)$ changes rapidly from $\approx 0$ to $\approx 1$ around $V = -50$ mV. What values of $V_\alpha$, $V_\beta$, $d_\alpha$, and $d_\beta$ did you use? What happens to the steepness of the curve if you make $|d_\alpha|$ and $|d_\beta|$ smaller?
#
# 2. **Time constant peak:** Keep $d_\alpha = -d_\beta$ and small (say $d_\alpha = 10$, $d_\beta = -10$). How does the location of the peak in $\tau_m(V)$ depend on $V_\alpha$ and $V_\beta$? Can you explain why the time constant is largest when $\alpha(V) \approx \beta(V)$?
#
# 3. **Activation vs. inactivation:** Can you find parameter values that produce an $m_\infty(V)$ curve that is _decreasing_ (high at negative voltages, low at positive voltages)? What does this represent biologically?
#
# 4. **Connecting to biology:** Based on what you know about the sodium channel, which set of parameters would you expect for the fast activation gate $m$, and which for the slow inactivation gate $h$?
