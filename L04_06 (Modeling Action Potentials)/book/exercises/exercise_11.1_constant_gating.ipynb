# %% [markdown]
# # Exercise 11.1: Gating with constant rates
#
# In this exercise, you will analyze the fundamental gating equation and explore its behavior using an interactive widget.
#
# ## 11.1a: Pen-and-paper — the equilibrium solution
#
# Consider the Hodgkin-Huxley gating equation for a single gate with _constant_ rate constants $\alpha$ and $\beta$:
#
# $$\frac{\mathrm{d}m}{\mathrm{d}t} = \alpha(1-m) - \beta m$$
#
# **Tasks:**
#
# 1. Find the equilibrium solution $m_\infty$ by setting $\frac{\mathrm{d}m}{\mathrm{d}t} = 0$ and solving for $m$. In terms of channel biophysics, what does this quantity represent?
#
# 2. For $\alpha, \beta > 0$, what is the range of values that $m_\infty$ can take? Why does this make biophysical sense?
#
# 3. The time constant of the equation is defined as $\tau_m = \frac{1}{\alpha + \beta}$. Reformulate the gating ODE using $m_\infty$ and $\tau_m$ instead of $\alpha$ and $\beta$. What kind of equation do you get?

# %% [markdown]
# ## 11.1b: Widget exploration
#
# Run the widget below to interactively explore the gating equation with constant rate constants.

# %%
from widgets import gating_widget

gating_widget()

# %% [markdown]
# **Tasks:**
#
# 1. **Verify your derivation:** Set $\alpha = 4$ and $\beta = 1$. Does the steady-state value match the $m_\infty$ you derived in 11.1a?
#
# 2. **Derive the fastest approach to $m_\infty = 0.8$:**
#    Starting from $m_\infty = \frac{\alpha}{\alpha + \beta} = 0.8$, express $\beta$ as a function of $\alpha$. Then substitute into the expression for $\tau_m$ and determine: how should you choose $\alpha$ to make $\tau_m$ as small as possible? Use the widget to verify your answer.
#
# 3. **Understand the roles of $\alpha$ and $\beta$:** If you multiply both $\alpha$ and $\beta$ by the same factor (e.g., double both), what happens to $m_\infty$? What happens to $\tau_m$? Why?
