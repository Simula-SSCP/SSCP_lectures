# %% [markdown]
# # Exercise 20.2: Thermodynamics of the NCX
#
# The sodium-calcium exchanger (NCX) transports 3 Na$^+$ ions in one direction and 1 Ca$^{2+}$ ion in the opposite direction. Crucially, NCX does **not** use any other source of energy such as ATP. In this exercise you will analyze the thermodynamics of this situation.

# %% [markdown]
# ## Exercise 20.2a: Passive or active transport?
#
# From what you recall about the terms _passive_ and _active_ ion transport, would you classify the NCX activity as passive or active? Explain your reasoning.

# %% [markdown]
# ## Exercise 20.2b: NCX Gibbs energy
#
# Explain why the change in Gibbs energy of one cycle of the NCX can be described as:
#
# $$
# \Delta G_{\mathrm{NCX}} = \Delta G_{\mathrm{Ca}} - 3\Delta G_{\mathrm{Na}}
# $$

# %% [markdown]
# ## Exercise 20.2c: Insert the Nernst potentials
#
# The change in Gibbs energy from moving an ion across the membrane depends on both the concentration gradient and the membrane potential:
#
# $$
# \Delta G_{\mathrm{X}} = z_{\mathrm{X}} F (E_{\mathrm{X}} - V)
# $$
#
# where $z_{\mathrm{X}}$ is the valency of ionic species X, $E_{\mathrm{X}}$ is its Nernst potential, $F$ is the Faraday constant, and $V$ is the membrane potential.
#
# Insert $\Delta G_{\mathrm{Na}}$ (with $z=1$) and $\Delta G_{\mathrm{Ca}}$ (with $z=2$) into the NCX Gibbs energy equation and simplify.

# %% [markdown]
# ## Exercise 20.2d: NCX reversal potential
#
# We know the system is at thermodynamic equilibrium when $\Delta G_{\mathrm{NCX}} = 0$. Find the _reversal potential_ of the NCX by solving:
#
# $$
# \Delta G_{\mathrm{NCX}} = 0
# $$
#
# for the membrane potential $V$. Show that this results in:
#
# $$
# E_{\mathrm{NCX}} = 3E_{\mathrm{Na}} - 2E_{\mathrm{Ca}}
# $$
#
# Explain how this potential relates to the forward and reverse modes of the exchanger.

# %% [markdown]
# ## Exercise 20.2e: Compute the NCX reversal potential
#
# In an earlier module, you computed the Nernst potentials under normal physiological conditions and found $E_{\mathrm{Na}} \approx 70$ mV and $E_{\mathrm{Ca}} \approx 114$ mV.
#
# Insert these values to find $E_{\mathrm{NCX}}$ in millivolts.

# %%
E_Na = ...  # mV
E_Ca = ...  # mV

E_NCX = ...

print(f"E_NCX = {E_NCX:.1f} mV")

# %% [markdown]
# ## Exercise 20.2f: The NCX during the action potential
#
# From your answer, do we expect to see any reverse mode of NCX during a normal action potential? If so, when in the action potential would we expect calcium to _enter_ the cell through NCX? When would calcium _leave_ the cell?
#
# Keep in mind that the intracellular calcium concentration changes substantially during an action potential, which shifts $E_{\mathrm{Ca}}$ and therefore $E_{\mathrm{NCX}}$.
