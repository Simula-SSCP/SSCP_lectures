# %% [markdown]
# # Exercise 20.1: Thermodynamic limits of the SERCA pump
#
# In this exercise, you will analyze the thermodynamic limits of the SERCA pump. Most of this exercise is pen-and-paper work (or Markdown), with a short computational part at the end.

# %% [markdown]
# ## Exercise 20.1a: SERCA and Gibbs energy
#
# Recall from the physical chemistry module that for any spontaneous process, we must have $\Delta G < 0$. Explain briefly why this is the case.
#
# For every cycle, the SERCA pump moves two calcium ions from the cytosol into the SR. This incurs a change in Gibbs energy of:
#
# $$
# \Delta G_{\mathrm{pump}} = 2RT \ln\left(\frac{[\mathrm{Ca}^{2+}]_{\mathrm{SR}}}{[\mathrm{Ca}^{2+}]_{\mathrm{i}}}\right)
# $$
#
# It is generally true that $[\mathrm{Ca}^{2+}]_{\mathrm{SR}} > [\mathrm{Ca}^{2+}]_{\mathrm{i}}$.
#
# 1. What does this mathematically mean for the sign of $\Delta G_{\mathrm{pump}}$?
# 2. What does your answer tell us about SERCA — is it passive or active transport? Why?

# %% [markdown]
# ## Exercise 20.1b: Coupling to ATP
#
# SERCA is an ATPase, meaning it breaks down one ATP molecule per cycle to power the pumping process. Explain why it must be the case that:
#
# $$
# \Delta G_{\mathrm{pump}} + \Delta G_{\mathrm{ATP}} < 0
# $$
#
# where $\Delta G_{\mathrm{ATP}}$ is the change in Gibbs energy from spending a single ATP molecule.

# %% [markdown]
# ## Exercise 20.1c: Maximum concentration ratio
#
# Insert the expression from 20.1a into 20.1b and solve for $[\mathrm{Ca}^{2+}]_{\mathrm{SR}}$. Show that this yields:
#
# $$
# [\mathrm{Ca}^{2+}]_{\mathrm{SR}} < [\mathrm{Ca}^{2+}]_{\mathrm{i}} \cdot \exp\left[\frac{-\Delta G_{\mathrm{ATP}}}{2RT}\right]
# $$
#
# Inside a mammalian myocyte, the energy released by ATP ($\Delta G_{\mathrm{ATP}}$) is roughly **−50 kJ/mol** (values in the literature range from 50–70 kJ/mol). At body temperature, $2RT \approx 5.2$ kJ/mol.
#
# Compute the absolute maximum concentration ratio ($[\mathrm{Ca}^{2+}]_{\mathrm{SR}} / [\mathrm{Ca}^{2+}]_{\mathrm{i}}$) that SERCA can theoretically maintain.

# %%
import numpy as np

# Compute the maximum concentration ratio
dG_ATP = ...  # kJ/mol (negative!)
two_RT = ...  # kJ/mol

max_ratio = ...

print(f"Maximum concentration ratio: {max_ratio:.0f}")

# %% [markdown]
# ## Exercise 20.1d: Theory vs. practice
#
# A commonly cited experimental finding is that SERCA can maintain a calcium gradient of about **1:7000**, i.e., the SR load can be at most 7000-fold higher than the cytosolic calcium.
#
# Compare this statement with your theoretical limit. If there are differences, discuss why this might be. Does it seem like SERCA is operating near its thermodynamic limit?
