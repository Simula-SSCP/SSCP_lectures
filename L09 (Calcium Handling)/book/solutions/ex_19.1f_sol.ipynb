# %% [markdown]
# # Exercise 19.1f solution
#
# The solutions show periodic oscillations in both cytosolic and SR calcium. When cytosolic calcium rises, the CICR mechanism amplifies the release from the SR, causing a spike. The spike is then cleared by the extrusion and uptake mechanisms, allowing the SR to refill. This cycle repeats, producing calcium oscillations — consistent with the experimental observations by Friel et al.
