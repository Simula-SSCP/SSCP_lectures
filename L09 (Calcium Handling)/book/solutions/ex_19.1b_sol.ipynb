# %% [markdown]
# # Exercise 19.1b solution
#
# $$\frac{\mathrm{d}[\mathrm{Ca}^{2+}]_{\mathrm{i}}}{\mathrm{d}t} = J_{\mathrm{entry}} + J_{\mathrm{rel}} - J_{\mathrm{extrusion}} - J_{\mathrm{uptake}}$$
#
# $$\frac{\mathrm{d}[\mathrm{Ca}^{2+}]_{\mathrm{SR}}}{\mathrm{d}t} = \frac{1}{\gamma}\left(J_{\mathrm{uptake}} - J_{\mathrm{rel}}\right)$$
#
# where $\gamma = 0.24$.
