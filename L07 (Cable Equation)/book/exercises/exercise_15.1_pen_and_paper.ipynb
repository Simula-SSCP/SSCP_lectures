# %% [markdown]
# # Exercise 15.1: The cable equation — pen-and-paper problems
#
# These exercises test your understanding of the cable equation derivation and the physical meaning of its parameters.

# %% [markdown]
# ## Exercise 15.1a: Dimensional analysis
#
# Verify that all the terms in the cable equation have the same physical dimensions:
#
# $$
# p\left(C_{\mathrm{m}}\frac{\partial V}{\partial t} + I_{\mathrm{ion}}(V)\right) = \frac{1}{r_e+r_i} \frac{\partial^2 V}{\partial x^2}
# $$
#
# Use the following typical units:
#
# | Quantity | Dimension | Typical unit |
# |----------|-----------|-------------|
# | $p$ | length | cm |
# | $C_{\mathrm{m}}$ | capacitance/area | µF/cm² |
# | $V$ | voltage | mV |
# | $I_{\mathrm{ion}}$ | current/area | µA/cm² |
# | $r_i, r_e$ | resistance/length | kΩ/cm |
# | $x$ | length | cm |
# | $t$ | time | ms |
#
# What is the physical unit of each side of the equation?

# %% [markdown]
# ## Exercise 15.1b: Computing the space constant
#
# Recall the expression for the space constant:
#
# $$
# \lambda_{\mathrm{m}} = \sqrt{\frac{R_{\mathrm{m}}}{p(r_i + r_e)}} \approx \sqrt{\frac{R_{\mathrm{m}}}{p \cdot r_i}} = \sqrt{\frac{R_{\mathrm{m}} A_i}{p \cdot R_c}}
# $$
#
# where we have assumed that $r_e \ll r_i$ (the extracellular resistance is negligible compared to the intracellular resistance).
#
# Assume a circular cross-section with diameter $d$. Typical values for a mammalian neuron are:
#
# - $R_{\mathrm{m}} = 7000\;\Omega\,\text{cm}^2$
# - $R_c = 150\;\Omega\,\text{cm}$
# - $d = 10.0\;\mu\text{m}$
#
# 1. Express $p$ and $A_i$ in terms of $d$.
# 2. Compute the space constant $\lambda_{\mathrm{m}}$ in centimetres.
# 3. A typical human motor neuron axon can be up to 1 metre long. How does $\lambda_{\mathrm{m}}$ compare? What does this imply about the need for active conduction?

# %%
import numpy as np

# Parameters
R_m = ...   # Ohm cm^2
R_c = ...   # Ohm cm
d = ...     # cm (convert from µm!)

# Cross-section and circumference
A_i = ...
p = ...

# Space constant
lambda_m = ...

print(f"Space constant: {lambda_m:.4f} cm")
print(f"Space constant: {lambda_m*10:.2f} mm")

# %% [markdown]
# ## Exercise 15.1c: Passive signal decay
#
# Consider a long passive dendrite with the space constant you computed above. If a synapse at position $x = 0$ generates a local potential of 10 mV:
#
# 1. What is the voltage 1 mm away from the synapse?
# 2. What is the voltage 1 cm away?
# 3. Would this passive signal be strong enough to trigger an action potential at the soma if the soma is 0.5 mm away? (Assume a typical firing threshold of ~15 mV above rest, and that the dendrite receives input from multiple synapses.)
