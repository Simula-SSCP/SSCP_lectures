# %% [markdown]
# # Exercise 2a solution

# %%
C = 100  # degrees Celsius
F = (9 / 5) * C + 32

print(f"100 degrees Celsius corresponds to {F} degrees Fahrenheit")
# Out:
# 100 degrees Celsius corresponds to 212.0 degrees Fahrenheit
