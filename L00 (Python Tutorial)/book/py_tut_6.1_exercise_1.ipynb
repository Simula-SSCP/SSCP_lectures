# %% [markdown]
# # Exercise 1: Python as a scientific calculator
#
# ![Earth](../fig/earth.png)
#
# The formula for the volume of a sphere is:
#
# $$
# V = \frac{4}{3}\pi R^3
# $$

# %% [markdown]
# ## Exercise 1a
#
# The Earth is close to a perfect sphere and has a radius of approximately **6371 km**. Compute the volume of the Earth.

# %%
# Code here

# %% [markdown]
# ## Exercise 1b
#
# Redo your computations, but this time, change the units around so that the answer is in number of liters.

# %%
# Code here

# %% [markdown]
# ## Exercise 1c
#
# The total mass of the Earth is approximately $M = 5.972 \times 10^{24}$ kg. Compute the average density of the Earth in terms of kg per liter. Does your answer seem reasonable?

# %%
# Code here
