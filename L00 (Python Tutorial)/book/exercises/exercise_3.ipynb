# %% [markdown]
# # Exercise 3: Grains of rice
#
# If we place one grain of rice on the first square of a chessboard, two grains on the second square, four grains on the third square, and so on for the rest of the board: How many grains of rice will we get in total?
#
# This can be written out as the sum:
#
# $$
# 1 + 2 + 4 + 8 + \dots
# $$
#
# ![Chessboard](../../fig/chessboard.png)

# %% [markdown]
# ## Exercise 3a
#
# Use a `for` loop and the `range()` function to loop over all 64 squares of the chessboard and find the total number of grains we get. Print your answer using scientific formatting (for example: `{total:.1e}`).

# %%
# Code here

# %% [markdown]
# ## Exercise 3b
#
# There are about **50,000** grains of rice in a **1 kg** bag. Use a `while` loop to find the exact number of squares we need to fill to get at least **1 kg** of rice.

# %%
# Code here
