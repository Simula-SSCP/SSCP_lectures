# %% [markdown]
# # Exercise 4: Functions and plotting
#
# ## Exercise 4a
#
# Define the two quadratic functions as Python functions:
#
# $$
# f(x) = x^2 + 4x - 6
# $$
#
# and
#
# $$
# g(x) = -2x^2 + 6x + 6
# $$

# %%
# Code here

# %% [markdown]
# ## Exercise 4b
#
# Import `numpy` as `np` and `matplotlib.pyplot` as `plt`.

# %%
# Code here

# %% [markdown]
# ## Exercise 4c
#
# Use `np.linspace` to define a large array of $x$-values between -5 and 5.

# %%
# Code here

# %% [markdown]
# ## Exercise 4d
#
# Use `plt.plot` to plot $f(x)$ and $g(x)$ into the same figure for $x \in [-5, 5]$.
#
# _(Hint: To plot two curves in the same plot, simply run two `plt.plot` commands before you call `plt.show()`)_.

# %%
# Code here

# %% [markdown]
# ## Exercise 4e
#
# (By eye) For what values of $x$ do the two functions intersect?
#
# ![Intersection](../../fig/intersection.png)
