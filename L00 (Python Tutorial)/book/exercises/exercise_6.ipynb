# %% [markdown]
# # Exercise 6: Finding the 10,001st prime number
#
# _(This exercise is taken from [projecteuler.net](https://projecteuler.net/problem=7), where it is Problem 7)._
#
# By listing the first six prime numbers: 2, 3, 5, 7, 11, and 13, we can clearly see that the 6th prime is 13.
#
# What is the **10,001st** prime number?

# %% [markdown]
# ## Exercise 6a
#
# To answer this question, first define a function `is_prime` that checks whether a given integer is a prime or not. Feel free to look at the example we built in the lecture notes.

# %%
# Code here

# %% [markdown]
# ## Exercise 6b
#
# Using your function, set up a `while` loop to keep checking for primes until you have found exactly 10,001 of them.

# %%
# Code here
