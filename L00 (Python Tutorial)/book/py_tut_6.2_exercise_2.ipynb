# %% [markdown]
# # Exercise 2: Converting temperatures
#
# ![Thermometer](../fig/thermo.png)
#
# To convert from degrees Celsius to degrees Fahrenheit you can use the formula:
#
# $$
# F = \frac{9}{5}C + 32
# $$

# %% [markdown]
# ## Exercise 2a
#
# Use the formula to compute how many degrees Fahrenheit **100°C** corresponds to.

# %%
# Code here

# %% [markdown]
# ## Exercise 2b
#
# Define a Python function called `C2F` which converts any given temperature from Celsius to Fahrenheit. Test that `C2F(100)` returns the same answer you found in 6.2a.

# %%
# Code here

# %% [markdown]
# ## Exercise 2c
#
# Define the inverse function, `F2C`, which takes degrees Fahrenheit as input, and returns the degrees Celsius as output.

# %%
# Code here
